# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %%
data = pd.read_csv('../data/customer_product_sales.csv')

# %%
data.head()
# Out:
#    CustomerID FirstName   LastName  SalesID  ProductID           ProductName  \
# 0       61288      Rosa   Andersen   134196        229  Bread - Hot Dog Buns
# 1       77352     Myron     Murray  6167892        229  Bread - Hot Dog Buns
# 2       40094     Susan  Stevenson  5970885        229  Bread - Hot Dog Buns
# 3       23548    Tricia    Vincent  6426954        229  Bread - Hot Dog Buns
# 4       78981     Scott      Burch   819094        229  Bread - Hot Dog Buns
#
#    Quantity
# 0        16
# 1        20
# 2        11
# 3         6
# 4        20

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
total = data.groupby(['CustomerID', 'ProductName'])['Quantity'].sum().reset_index()
total
# Out:
#        CustomerID                        ProductName  Quantity
# 0              33                   Apricots - Dried         1
# 1              33                  Assorted Desserts         1
# 2              33            Bandage - Flexible Neon         1
# 3              33      Bar Mix - Pina Colada, 355 Ml         1
# 4              33             Beans - Kidney, Canned         1
# 5              33             Beef - Chuck, Boneless         1
# 6              33               Beef - Prime Rib Aaa         1
# 7              33      Beer - Original Organic Lager         1
# 8              33                Beer - Rickards Red         1
# 9              33                     Black Currants         1
# 10             33                       Blackberries         1
# 11             33    Bread - Italian Roll With Herbs         1
# 12             33               Bread Foccacia Whole         1
# 13             33        Cake - Box Window 10x10x2.5         1
# ...

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
pivtab = total.pivot_table(index='ProductName', columns='CustomerID', values='Quantity', fill_value=0)

# %%
pivtab.head()
# Out:
# CustomerID                         33     200    264    356    412    464    \
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0      0      0      0
# Apricots - Dried                       1      0      0      0      1      0
#
# CustomerID                         477    639    649    669    ...  97697  \
# ProductName                                                    ...
# Anchovy Paste - 56 G Tube              0      1      0      0  ...      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0  ...     25
# Appetizer - Mushroom Tart              0      1      0      0  ...     25
# Appetizer - Sausage Rolls              0      0      0      0  ...      0
# ...

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
distance = pd.DataFrame(1/(1 + squareform(pdist(pivtab.T, 'euclidean'))), 
                         index=pivtab.columns, columns=pivtab.columns)

# %%
distance
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.077421  0.087047  0.081800  0.080634  0.082709
# 200         0.077421  1.000000  0.078448  0.076435  0.073693  0.075255
# 264         0.087047  0.078448  1.000000  0.080070  0.081800  0.080350
# 356         0.081800  0.076435  0.080070  1.000000  0.076435  0.078187
# 412         0.080634  0.073693  0.081800  0.076435  1.000000  0.078711
# 464         0.082709  0.075255  0.080350  0.078187  0.078711  1.000000
# 477         0.074573  0.075956  0.076923  0.075025  0.075025  0.074798
# 639         0.083020  0.076435  0.080634  0.082403  0.082403  0.084626
# 649         0.081503  0.077674  0.082100  0.077171  0.078187  0.080070
# 669         0.080070  0.076923  0.078448  0.075956  0.078448  0.078187
# 694         0.078977  0.075025  0.080070  0.076923  0.075956  0.079246
# 756         0.083651  0.075956  0.082403  0.076435  0.078448  0.078187
# ...

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
id_rand = data.CustomerID.sample(1).iloc[0]

top = distance[id_rand].sort_values(ascending=False).index.tolist()[1:6]
top
# Out:
# [20446, 13062, 13912, 6447, 7021]

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
top_df = data[data.CustomerID.isin(top)]
top_df
# Out:
#        CustomerID  FirstName  LastName  SalesID  ProductID  \
# 59          13912     Billie     Quinn  4750757        229
# 221          6447      Ellen   Bradley  4350625        270
# 378          6447      Ellen   Bradley  5082833        153
# 982         20446  Cassandra     Weiss  4545773        417
# 983         20446  Cassandra     Weiss  5546679        417
# 1647         6447      Ellen   Bradley  1364567         69
# 1920        20446  Cassandra     Weiss   533786        244
# 2066        13912     Billie     Quinn  3214620        427
# 2067        13912     Billie     Quinn  3801126        427
# 2099         6447      Ellen   Bradley  1008429        427
# 2335         7021    Suzanne  Mitchell   423874         44
# 2801        13062      Cathy     Brady  6705072        409
# 2817        20446  Cassandra     Weiss  5794791        409
# 2978        20446  Cassandra     Weiss  3650106        214
# 3145        13912     Billie     Quinn  1363265         85
# ...

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
new = top_df.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False)
new
# Out:
# ProductName
# Assorted Desserts                16
# Shrimp - Baby, Warm Water        16
# Milk - 2%                        16
# Soup - Campbells, Beef Barley    14
# Cattail Hearts                   14
# Bouq All Italian - Primerba      14
# Hinge W Undercut                 12
# Veal - Eye Of Round              12
# Bread - French Baquette          12
# Cheese - Cottage Cheese          12
# Beer - Sleemans Cream Ale        12
# Lamb - Pieces, Diced             12
# Coffee - Hazelnut Cream          12
# Beef - Short Loin                12
# Crab - Imitation Flakes          12
# Brandy - Bar                     12
# Oregano - Dry, Rubbed            10
# Sprouts - Baby Pea Tendrils      10
# Skirt - 29 Foot                  10
# Lettuce - California Mix         10
# Shrimp - 31/40                   10
# Halibut - Fletches               10
# Mayonnaise - Individual Pkg      10
# Juice - Lime                     10
# Scallops 60/80 Iqf               10
# ...

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
reco = [i for i in new.index if not i in data['ProductName'][data.CustomerID == 200].unique()]
new[new.index.isin(reco)][:5]
# Out:
# ProductName
# Assorted Desserts                16
# Shrimp - Baby, Warm Water        16
# Milk - 2%                        16
# Soup - Campbells, Beef Barley    14
# Cattail Hearts                   14
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
recomm = {}

for ID in data.CustomerID.unique():    
    top = distance[ID].sort_values(ascending=False)[1:6].index.tolist()[1:6]
    top_df = total[total.CustomerID.isin(top)]
    ID_p = top_df.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False) 
    ID_pnb = [i for i in ID_p.index if not i in data['ProductName'][data.CustomerID == id_rand].unique()]
    recomm[ID] = ID_p[ID_p.index.isin(ID_pnb)][:5].index.tolist()

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
euclidean_r = pd.DataFrame(recomm).T
euclidean_r.columns = ['P1', 'P2', 'P3', 'P4', 'P5']
euclidean_r.head()
# Out:
#                                    P1                     P2  \
# 61288             Beef - Inside Round     Beef - Rib Eye Aaa
# 77352             Chicken - Soup Base          Puree - Mocha
# 40094  Bread - Italian Corn Meal Poly  Oregano - Dry, Rubbed
# 23548                          Pernod    Flavouring - Orange
# 78981                   Vanilla Beans                Isomalt
#
#                                    P3                             P4  \
# 61288                    Jagermeister  Wine - Prosecco Valdobiaddene
# 77352        Wine - Valpolicella Masi                    Fuji Apples
# 40094                    Sherry - Dry               Halibut - Steaks
# 23548  Wine - Magnotta, Merlot Sr Vqa             Sauce - Demi Glace
# 78981              Crush - Cream Soda                Tea - Earl Grey
#
#                         P5
# 61288  Chicken - Soup Base
# 77352         Sugar - Fine
# 40094      Grouper - Fresh
# 23548  Juice - Apple Cider
# 78981     Lettuce - Frisee

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, consine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
cos = pd.DataFrame(1/(1 + squareform(pdist(pivtab.T, 'cosine'))), 
                   index=pivtab.columns, columns=pivtab.columns)
recomm = {}

for ID in data.CustomerID.unique():    
    top = cos[ID].sort_values(ascending=False)[1:6].index.tolist()[1:6]
    top_df = total[total.CustomerID.isin(top)]
    ID_p = top_df.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False) 
    ID_pnb = [i for i in ID_p.index if not i in data['ProductName'][data.CustomerID == id_rand].unique()]
    recomm[ID] = ID_p[ID_p.index.isin(ID_pnb)][:5].index.tolist()

# %%
cosine_r = pd.DataFrame(recomm).T
cosine_r.columns = ['P1', 'P2', 'P3', 'P4', 'P5']
cosine_r.head()
# Out:
#                                      P1                          P2  \
# 61288  Longos - Grilled Salmon With Bbq  Wine - Two Oceans Cabernet
# 77352                Cheese - Camembert            Scallops - 10/20
# 40094                     Cumin - Whole           Juice - V8 Splash
# 23548                 Snapple Lemon Tea               Bagel - Plain
# 78981     Wine - Blue Nun Qualitatswein     Cheese - Cottage Cheese
#
#                                P3                           P4  \
# 61288    Wine - Fume Blanc Fetzer                 Jagermeister
# 77352  Spice - Peppercorn Melange              Fondant - Icing
# 40094         Beef - Inside Round  Cheese - Brie, Triple Creme
# 23548        Cinnamon Buns Sticky       Bread - English Muffin
# 78981                     Isomalt           Cookies - Assorted
#
#                                    P5
# 61288                     Tofu - Firm
# 77352  Beef - Montreal Smoked Brisket
# 40094          Cake - Mini Cheesecake
# ...
