# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform
print('librerias importadas')
# Out:
# librerias importadas

# %%
data = pd.read_csv('../data/customer_product_sales.csv')

# %%
data.head()
# Out:
#    CustomerID FirstName   LastName  SalesID  ProductID           ProductName  \
# 0       61288      Rosa   Andersen   134196        229  Bread - Hot Dog Buns
# 1       77352     Myron     Murray  6167892        229  Bread - Hot Dog Buns
# 2       40094     Susan  Stevenson  5970885        229  Bread - Hot Dog Buns
# 3       23548    Tricia    Vincent  6426954        229  Bread - Hot Dog Buns
# 4       78981     Scott      Burch   819094        229  Bread - Hot Dog Buns
#
#    Quantity
# 0        16
# 1        20
# 2        11
# 3         6
# 4        20

# %%
data.sort_values('CustomerID', ascending=True).head(5)
# Out:
#        CustomerID FirstName LastName  SalesID  ProductID  \
# 14280          33   Lindsay  Santana  2005605        162
# 3012           33   Lindsay  Santana  5638266        214
# 18070          33   Lindsay  Santana  5056183        387
# 4118           33   Lindsay  Santana  1888258         53
# 53450          33   Lindsay  Santana   140335        245
#
#                           ProductName  Quantity
# 14280              Sauce - Demi Glace         1
# 3012   French Pastry - Mini Chocolate         1
# 18070                 Fondant - Icing         1
# 4118                           Cassis         1
# 53450                 Grouper - Fresh         1

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
productos = pd.DataFrame(data.groupby(['CustomerID','ProductName'])['Quantity'].sum())
productos.head()
# Out:
#                                           Quantity
# CustomerID ProductName
# 33         Apricots - Dried                      1
#            Assorted Desserts                     1
#            Bandage - Flexible Neon               1
#            Bar Mix - Pina Colada, 355 Ml         1
#            Beans - Kidney, Canned                1

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
tablita = pd.pivot_table(data, values = 'Quantity', index = ['ProductName'], columns=['CustomerID']).fillna(0)
#tablita

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
cuadradoeuclides = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'euclidean'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradoeuclides.head(6)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.085297  0.093953  0.091747  0.087410  0.089695
# 200         0.085297  1.000000  0.085638  0.085297  0.080070  0.083020
# 264         0.093953  0.085638  1.000000  0.088152  0.089301  0.087047
# 356         0.091747  0.085297  0.088152  1.000000  0.085983  0.086688
# 412         0.087410  0.080070  0.089301  0.085983  1.000000  0.085638
# 464         0.089695  0.083020  0.087047  0.086688  0.085638  1.000000
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.085297  0.088913  0.088152  0.089695  ...  0.004809  0.005108
# 200         0.084959  0.083651  0.085638  0.087047  ...  0.004825  0.005121
# 264         0.085638  0.086333  0.087047  0.087047  ...  0.004822  0.005115
# 356         0.085983  0.091325  0.085983  0.087410  ...  0.004814  0.005111
# 412         0.085638  0.089301  0.084959  0.087779  ...  0.004808  0.005131
# 464         0.085638  0.092610  0.087779  0.087047  ...  0.004814  0.005121
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.004996  0.005421  0.004920  0.005023  0.004880  0.005026
# 200         0.005014  0.005448  0.004925  0.005032  0.004909  0.005042
# 264         0.004996  0.005441  0.004932  0.005055  0.004894  0.005042
# 356         0.004999  0.005437  0.004920  0.005036  0.004871  0.005042
# 412         0.004996  0.005441  0.004925  0.005042  0.004876  0.005039
# 464         0.004993  0.005445  0.004920  0.005042  0.004877  0.005039
#
# CustomerID     98185     98200
# CustomerID
# 33          0.004549  0.004883
# 200         0.004553  0.004879
# 264         0.004566  0.004883
# 356         0.004563  0.004886
# 412         0.004568  0.004903
# 464         0.004556  0.004897
#
# [6 rows x 1000 columns]

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
lista = cuadradoeuclides.sort_values([33], ascending=False).head(6).reset_index()
lista
# Out:
# CustomerID  CustomerID        33       200       264       356       412  \
# 0                   33  1.000000  0.085297  0.093953  0.091747  0.087410
# 1                 3909  0.095358  0.089695  0.088913  0.088530  0.088913
# 2                 3531  0.093953  0.084297  0.086333  0.088913  0.085638
# 3                  264  0.093953  0.085638  1.000000  0.088152  0.089301
# 4                 2503  0.093498  0.088152  0.088913  0.092610  0.088152
# 5                 3305  0.093051  0.084959  0.090909  0.093953  0.087047
#
# CustomerID       464       477       639       649  ...     97697     97753  \
# 0           0.089695  0.085297  0.088913  0.088152  ...  0.004809  0.005108
# 1           0.088152  0.088913  0.090499  0.088152  ...  0.004809  0.005118
# 2           0.087779  0.087047  0.086333  0.089301  ...  0.004814  0.005125
# 3           0.087047  0.085638  0.086333  0.087047  ...  0.004822  0.005115
# 4           0.093953  0.088913  0.093051  0.093051  ...  0.004815  0.005109
# 5           0.088530  0.087779  0.092610  0.089301  ...  0.004812  0.005112
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# 0           0.004996  0.005421  0.004920  0.005023  0.004880  0.005026
# 1           0.004990  0.005433  0.004920  0.005036  0.004880  0.005020
# 2           0.004990  0.005437  0.004923  0.005049  0.004891  0.005042
# 3           0.004996  0.005441  0.004932  0.005055  0.004894  0.005042
# 4           0.004994  0.005422  0.004912  0.005043  0.004878  0.005030
# 5           0.005003  0.005422  0.004917  0.005036  0.004871  0.005036
#
# CustomerID     98185     98200
# 0           0.004549  0.004883
# 1           0.004554  0.004889
# 2           0.004551  0.004877
# 3           0.004566  0.004883
# 4           0.004559  0.004869
# 5           0.004559  0.004880
#
# [6 rows x 1001 columns]

# %%
iguales = list(lista.CustomerID[1:])

# %%
iguales
# Out:
# [3909, 3531, 264, 2503, 3305]

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
#dataframe creado en el paso 1
#productos.head()

# %%
productos2 = productos.reset_index()
productos2.set_index(['CustomerID'], inplace = True)
productos2
# Out:
#                                   ProductName  Quantity
# CustomerID
# 33                           Apricots - Dried         1
# 33                          Assorted Desserts         1
# 33                    Bandage - Flexible Neon         1
# 33              Bar Mix - Pina Colada, 355 Ml         1
# 33                     Beans - Kidney, Canned         1
# 33                     Beef - Chuck, Boneless         1
# 33                       Beef - Prime Rib Aaa         1
# 33              Beer - Original Organic Lager         1
# 33                        Beer - Rickards Red         1
# 33                             Black Currants         1
# 33                               Blackberries         1
# 33            Bread - Italian Roll With Herbs         1
# 33                       Bread Foccacia Whole         1
# 33                Cake - Box Window 10x10x2.5         1
# 33                                     Cassis         1
# 33                    Cheese - Cottage Cheese         1
# 33                    Crab - Imitation Flakes         1
# 33                            Fondant - Icing         1
# 33             French Pastry - Mini Chocolate         1
# 33                    General Purpose Trigger         1
# 33                               Grapes - Red         1
# 33                            Grouper - Fresh         2
# 33                              Hersey Shakes         1
# 33                  Ice Cream Bar - Drumstick         1
# 33                       Lamb - Pieces, Diced         1
# 33                       Lettuce - Spring Mix         2
# 33                                    Mangoes         1
# 33                     Muffin Batt - Choc Chk         1
# 33                           Onions - Vidalia         1
# 33          Pasta - Cheese / Spinach Bauletti         1
# ...                                       ...       ...
# 98200                            Onion Powder        25
# 98200               Orange - Canned, Mandarin        25
# 98200          Pasta - Detalini, White, Fresh        25
# 98200                   Puree - Passion Fruit        25
# 98200                     Raspberries - Fresh        25
# 98200                       Rice - Long Grain        25
# 98200                          Rosemary - Dry        25
# 98200              Rosemary - Primerba, Paste        50
# 98200                   Rum - Coconut, Malibu        25
# 98200                           Sage - Ground        25
# 98200                         Sausage - Liver        25
# 98200                        Sea Bass - Whole        50
# 98200                Seedlings - Mix, Organic        25
# 98200              Sole - Dover, Whole, Fresh        25
# 98200                Soup - Campbells, Lentil        50
# 98200        Soup Campbells - Italian Wedding        25
# 98200             Soup Knorr Chili With Beans        25
# 98200                 Soupfoamcont12oz 112con        25
# 98200                          Spinach - Baby        25
# 98200                 Table Cloth 54x72 White        25
# 98200                 Tea - English Breakfast        25
# 98200                       Tilapia - Fillets        25
# 98200                      Tomatoes Tear Drop        25
# 98200                    Truffle Cups - Brown        25
# 98200                        Vaccum Bag 10x13        25
# 98200                            Vol Au Vents        50
# 98200                           Wasabi Powder        25
# 98200                Wine - Fume Blanc Fetzer        25
# 98200           Wine - Hardys Bankside Shiraz        25
# 98200                 Yogurt - French Vanilla        25
#
# [63628 rows x 2 columns]

# %%
#Reviso si el indice de productos2 esta en iguales y lo guardo en acotado y uso loc para solo traer las filas que cumplan esa condicion
acotado = productos2.loc[productos2.index.isin(iguales)]

# %%
#comprobamos que el CustomerID sea el que necesito
acotado.head()
# Out:
#                            ProductName  Quantity
# CustomerID
# 264                  Apricots - Halves         1
# 264                     Apricots Fresh         1
# 264         Bacardi Breezer - Tropical         1
# 264                      Bagel - Plain         1
# 264                    Banana - Leaves         1

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
simi.reset_index(inplace=True)

# %%
print(simi.ProductName)
# Out:
# 0                      Salsify, Organic
# 1          Wine - Charddonnay Errazuriz
# 2         Wine - Ej Gallo Sierra Valley
# 3                   Oranges - Navel, 72
# 4                       Quiche Assorted
# 5                              Bay Leaf
# 6                  Pecan Raisin - Tarts
# 7                      Chocolate - Dark
# 8                Towels - Paper / Kraft
# 9                           Tofu - Firm
# 10                        Sauce - Rosee
# 11                             Sardines
# 12        Pork - Hock And Feet Attached
# 13                       Black Currants
# 14                           Sauerkraut
# 15                     Eggplant - Asian
# 16                     V8 - Berry Blend
# 17                        Chef Hat 20cm
# 18          Beets - Candy Cane, Organic
# 19            Ice Cream Bar - Oreo Cone
# 20     Oil - Shortening - All - Purpose
# 21                      Sausage - Liver
# 22                           Dried Figs
# 23                  Squid U5 - Thailand
# 24                          Bread - Rye
# 25                 Bread Crumbs - Panko
# 26                 Curry Paste - Madras
# 27                  Cheese Cloth No 100
# 28                    Butter - Unsalted
# 29                              Isomalt
#                      ...
# 205                    Lettuce - Frisee
# 206            Lettuce - California Mix
# 207          Lemonade - Natural, 591 Ml
# 208        Langers - Ruby Red Grapfruit
# 209      Pasta - Detalini, White, Fresh
# 210          Pasta - Penne, Rigate, Dry
# 211                      Shrimp - 31/40
# 212         Pastry - Butterscotch Baked
# 213                    Sea Bass - Whole
# 214                         Scampi Tail
# 215                    Scallops - 10/20
# 216                Scallop - St. Jaques
# 217                 Sausage - Breakfast
# 218                 Sauce - Hollandaise
# 219                  Sauce - Demi Glace
# 220                Salmon - Sockeye Raw
# 221                       Sage - Ground
# 222          Rosemary - Primerba, Paste
# 223                 Raspberries - Fresh
# 224                       Pork - Kidney
# 225                       Pork - Inside
# 226         Pork - Bacon, Double Smoked
# 227                             Pomello
# 228           Placemat - Scallop, White
# 229                Pie Filling - Cherry
# 230                Pepsi - Diet, 355 Ml
# 231              Pepper - White, Ground
# 232                  Peas - Pigeon, Dry
# 233        Pastry - Cheese Baked Scones
# 234           Appetizer - Mushroom Tart
# Name: ProductName, Length: 235, dtype: object

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
treintaytres = data[data['CustomerID']==33]
productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
productos33.reset_index(inplace = True)

# %%
df_inner = pd.merge(simi, productos33, on='ProductName', how='left')

# %%
df_inner
# Out:
#                           ProductName  Quantity_x  Quantity_y
# 0                    Salsify, Organic           4         2.0
# 1        Wine - Charddonnay Errazuriz           3         NaN
# 2       Wine - Ej Gallo Sierra Valley           3         NaN
# 3                 Oranges - Navel, 72           3         NaN
# 4                     Quiche Assorted           3         1.0
# 5                            Bay Leaf           3         NaN
# 6                Pecan Raisin - Tarts           3         NaN
# 7                    Chocolate - Dark           3         NaN
# 8              Towels - Paper / Kraft           2         1.0
# 9                         Tofu - Firm           2         NaN
# 10                      Sauce - Rosee           2         NaN
# 11                           Sardines           2         NaN
# 12      Pork - Hock And Feet Attached           2         1.0
# 13                     Black Currants           2         1.0
# 14                         Sauerkraut           2         NaN
# 15                   Eggplant - Asian           2         NaN
# 16                   V8 - Berry Blend           2         NaN
# 17                      Chef Hat 20cm           2         NaN
# 18        Beets - Candy Cane, Organic           2         NaN
# 19          Ice Cream Bar - Oreo Cone           2         NaN
# 20   Oil - Shortening - All - Purpose           2         NaN
# 21                    Sausage - Liver           2         NaN
# 22                         Dried Figs           2         NaN
# 23                Squid U5 - Thailand           2         NaN
# 24                        Bread - Rye           2         NaN
# 25               Bread Crumbs - Panko           2         NaN
# 26               Curry Paste - Madras           2         NaN
# 27                Cheese Cloth No 100           2         NaN
# 28                  Butter - Unsalted           2         NaN
# 29                            Isomalt           2         NaN
# ..                                ...         ...         ...
# 205                  Lettuce - Frisee           1         NaN
# 206          Lettuce - California Mix           1         NaN
# 207        Lemonade - Natural, 591 Ml           1         NaN
# 208      Langers - Ruby Red Grapfruit           1         NaN
# 209    Pasta - Detalini, White, Fresh           1         NaN
# 210        Pasta - Penne, Rigate, Dry           1         NaN
# 211                    Shrimp - 31/40           1         NaN
# 212       Pastry - Butterscotch Baked           1         NaN
# 213                  Sea Bass - Whole           1         NaN
# 214                       Scampi Tail           1         NaN
# 215                  Scallops - 10/20           1         NaN
# 216              Scallop - St. Jaques           1         NaN
# 217               Sausage - Breakfast           1         NaN
# 218               Sauce - Hollandaise           1         NaN
# 219                Sauce - Demi Glace           1         1.0
# 220              Salmon - Sockeye Raw           1         NaN
# 221                     Sage - Ground           1         NaN
# 222        Rosemary - Primerba, Paste           1         NaN
# 223               Raspberries - Fresh           1         NaN
# 224                     Pork - Kidney           1         NaN
# 225                     Pork - Inside           1         NaN
# 226       Pork - Bacon, Double Smoked           1         1.0
# 227                           Pomello           1         NaN
# 228         Placemat - Scallop, White           1         NaN
# 229              Pie Filling - Cherry           1         NaN
# 230              Pepsi - Diet, 355 Ml           1         NaN
# 231            Pepper - White, Ground           1         1.0
# 232                Peas - Pigeon, Dry           1         NaN
# 233      Pastry - Cheese Baked Scones           1         NaN
# 234         Appetizer - Mushroom Tart           1         NaN
#
# [235 rows x 3 columns]

# %%
nocomprados = df_inner[df_inner.Quantity_y.isna()]
nocomprados2 = nocomprados.reset_index()
nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
nocomprados3
# Out:
#                            ProductName  Quantity_x
# 0      Muffin - Carrot Individual Wrap           5
# 1     Cheese - Boursin, Garlic / Herbs           4
# 2                        Pork - Kidney           4
# 3       Pasta - Detalini, White, Fresh           3
# 4                  Raspberries - Fresh           3
# 5               Beans - Kidney, Canned           3
# 6                      Sausage - Liver           3
# 7        Ice Cream Bar - Hageen Daz To           3
# 8             Kellogs Special K Cereal           3
# 9                   Beef Ground Medium           3
# 10                     Beef Wellington           3
# 11               Knife Plastic - White           3
# 12                        Berry Brulee           2
# 13                    Olives - Stuffed           2
# 14                        Broom - Corn           2
# 15                   Butter - Unsalted           2
# 16               Oregano - Dry, Rubbed           2
# 17               Otomegusa Dashi Konbu           2
# 18                 Oranges - Navel, 72           2
# 19    Oil - Shortening - All - Purpose           2
# 20                  Tea - Decaf Lipton           2
# 21          Pasta - Penne, Rigate, Dry           2
# 22           Ecolab - Mikroklene 4/4 L           2
# 23                       Sauce - Rosee           2
# 24                Pecan Raisin - Tarts           2
# 25                            Sardines           2
# 26                    Salsify, Organic           2
# 27      Chips Potato All Dressed - 43g           2
# 28       Chips Potato Salt Vinegar 43g           2
# 29               Puree - Passion Fruit           2
# ..                                 ...         ...
# 146         Yogurt - Blueberry, 175 Gr           1
# 147           Nut - Pistachio, Shelled           1
# 148             Nut - Chestnuts, Whole           1
# 149                   Mustard Prepared           1
# 150            Mushroom - Trumpet, Dry           1
# 151            Mushroom - Porcini, Dry           1
# 152            Meldea Green Tea Liquor           1
# 153          Macaroons - Two Bite Choc           1
# 154   Longos - Grilled Salmon With Bbq           1
# 155      Longos - Grilled Chicken With           1
# 156               Liners - Baking Cups           1
# 157               Lettuce - Spring Mix           1
# 158           Lettuce - California Mix           1
# 159       Pastry - Cheese Baked Scones           1
# 160                 Peas - Pigeon, Dry           1
# 161                     Shrimp - 31/40           1
# 162              Pepper - Black, Whole           1
# 163                       Sherry - Dry           1
# 164                   Sea Bass - Whole           1
# 165               Scallop - St. Jaques           1
# 166                Sausage - Breakfast           1
# 167                Sauce - Hollandaise           1
# 168               Salmon - Sockeye Raw           1
# 169         Rosemary - Primerba, Paste           1
# 170              Rice - Jasmine Sented           1
# 171         Potatoes - Idaho 100 Count           1
# 172               Pie Filling - Cherry           1
# 173               Pepsi - Diet, 355 Ml           1
# 174        Pepper - Paprika, Hungarian           1
# 175  Appetizer - Mini Egg Roll, Shrimp           1
#
# [176 rows x 2 columns]

# %%
top5 = nocomprados.head(5)
top5
# Out:
#                      ProductName  Quantity_x
# 0   Wine - Charddonnay Errazuriz           3
# 1  Wine - Ej Gallo Sierra Valley           3
# 2            Oranges - Navel, 72           3
# 3                       Bay Leaf           3
# 4           Pecan Raisin - Tarts           3

# %%
#recomendaciones['CustomerID']=
recomendaciones[0]=top5.ProductName[0]
recomendaciones[1]=top5.ProductName[1]
recomendaciones[2]=top5.ProductName[2]
recomendaciones[3]=top5.ProductName[3]
recomendaciones[4]=top5.ProductName[4]

# %%
recomendaciones
# Out:
# {0: 'Wine - Charddonnay Errazuriz',
#  1: 'Wine - Ej Gallo Sierra Valley',
#  2: 'Oranges - Navel, 72',
#  3: 'Bay Leaf',
#  4: 'Pecan Raisin - Tarts'}

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
recomendaciones=dict()
listarecomendaciones= []
clientes = data.CustomerID.unique()

# %%
for cliente in clientes:
    lista = cuadradoeuclides.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    recomendaciones['CustomerID']= cliente
    recomendaciones[0]=top5.ProductName[0]
    recomendaciones[1]=top5.ProductName[1]
    recomendaciones[2]=top5.ProductName[2]
    recomendaciones[3]=top5.ProductName[3]
    recomendaciones[4]=top5.ProductName[4]
    listarecomendaciones.append(recomendaciones.copy())

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
tonio = pd.DataFrame(listarecomendaciones)
tonio.set_index('CustomerID', inplace = True)

# %%
tonio
# Out:
#                                             0  \
# CustomerID
# 61288                Mushrooms - Black, Dried
# 77352                             Guinea Fowl
# 40094                Water - Mineral, Natural
# 23548                             Wanton Wrap
# 78981                        Lettuce - Frisee
# 83106        Cheese - Boursin, Garlic / Herbs
# 11253              Smirnoff Green Apple Twist
# 35107                     Flavouring - Orange
# 15088              Smirnoff Green Apple Twist
# 26031                  Muffin Batt - Choc Chk
# 86595            Wine - Charddonnay Errazuriz
# 46715                            Brandy - Bar
# 91013                        Chocolate - Dark
# 69931                                 Papayas
# 19753                            Tahini Paste
# 9546                  Olive - Spread Tapenade
# 10224                     Cheese - Mozzarella
# 72846                   Kellogs All Bran Bars
# 28976             Pork - Bacon, Double Smoked
# 3267               Sole - Dover, Whole, Fresh
# 19260                     Cheese - Mozzarella
# 76530                       Tilapia - Fillets
# 30196                  Beef - Chuck, Boneless
# 48818           Wine - Wyndham Estate Bin 777
# 15166                          Spinach - Baby
# 11443                Wine - Pinot Noir Latour
# 79060                      Beef Ground Medium
# 82597                 Table Cloth 81x81 White
# 62411                    Bread Fig And Almond
# 42611             Beets - Candy Cane, Organic
# ...                                       ...
# 95034                      Vinegar - Tarragon
# 5986                Appetizer - Sausage Rolls
# 88159                       Assorted Desserts
# 17458                       Lettuce - Treviso
# 93505          French Pastry - Mini Chocolate
# 46826                       Crackers Cheez It
# 15371                        Scallops - 10/20
# 49981           Chips Potato Salt Vinegar 43g
# 79353                       Wiberg Super Cure
# 57991                             Fuji Apples
# 6734              Wine - White, Colubia Cresh
# 2902                            Pork - Kidney
# 86136                             Fuji Apples
# 33051                      Tea - Jasmin Green
# 3253                 Cod - Black Whole Fillet
# 33320                  Pepper - White, Ground
# 62719                  Cookie - Dough Variety
# 12852                           Lamb - Ground
# 76796            Wine - Charddonnay Errazuriz
# 10114                          Apricots Fresh
# 25270                        Eggplant - Asian
# 17390                 Coffee - Hazelnut Cream
# 97029           Wine - Vidal Icewine Magnotta
# 38154                 Rum - Mount Gay Eclipes
# 74403              Bacardi Breezer - Tropical
# 49005                 Olive - Spread Tapenade
# 41286                           Veal - Inside
# 85878        Beef - Ground, Extra Lean, Fresh
# 68506       Pasta - Cheese / Spinach Bauletti
# 3472          Muffin - Carrot Individual Wrap
#
#                                            1  \
# CustomerID
# 61288         Wine - Magnotta, Merlot Sr Vqa
# 77352                              Grenadine
# 40094                  Oregano - Dry, Rubbed
# 23548                         Banana Turning
# 78981                 Longos - Chicken Wings
# 83106                        Garlic - Peeled
# 11253                      Lettuce - Treviso
# 35107          Ice Cream Bar - Hageen Daz To
# 15088                            Blueberries
# 26031                     Beef - Top Sirloin
# 86595            Pastry - Butterscotch Baked
# 46715                      Tilapia - Fillets
# 91013                    Sauce - Hollandaise
# 69931          Beef - Tenderlion, Center Cut
# 19753                Pastry - Choclate Baked
# 9546           Wine - Ej Gallo Sierra Valley
# 10224          Ice Cream Bar - Hageen Daz To
# 72846                  Ecolab - Solid Fusion
# 28976                    Cheese Cloth No 100
# 3267                         Quiche Assorted
# 19260          Ice Cream Bar - Hageen Daz To
# 76530            Pastry - Butterscotch Baked
# 30196                    Coffee - Dark Roast
# 48818           Soup - Canadian Pea, Dry Mix
# 15166                    Tray - 16in Rnd Blk
# 11443                      Veal - Sweetbread
# 79060                              Milk - 1%
# 82597                  Veal - Inside, Choice
# 62411                  Veal - Inside, Choice
# 42611             Potatoes - Instant, Mashed
# ...                                      ...
# 95034                      Snapple Lemon Tea
# 5986              Bacardi Breezer - Tropical
# 88159              Shrimp - Baby, Warm Water
# 17458                          Lamb - Ground
# 93505                  Pop Shoppe Cream Soda
# 46826                   Sun - Dried Tomatoes
# 15371                   Scallop - St. Jaques
# 49981             Rosemary - Primerba, Paste
# 79353                           Tahini Paste
# 57991            Cake - Box Window 10x10x2.5
# 6734           Ice Cream Bar - Hageen Daz To
# 2902        Cheese - Boursin, Garlic / Herbs
# 86136                        Crackers - Trio
# 33051                    Beets - Mini Golden
# 3253             Sprouts - Baby Pea Tendrils
# 33320                Wine - Redchard Merritt
# 62719                 Ocean Spray - Ruby Red
# 12852                            Beans - Wax
# 76796                      Apricots - Halves
# 10114                  Otomegusa Dashi Konbu
# 25270            Soup Knorr Chili With Beans
# 17390                    Cheese Cloth No 100
# 97029            Cake - Box Window 10x10x2.5
# 38154               Table Cloth 62x114 White
# 74403                   Lamb - Pieces, Diced
# 49005                  Veal - Inside, Choice
# 41286                   Bread Foccacia Whole
# 85878                 Cookie - Dough Variety
# 68506                     Doilies - 5, Paper
# 3472        Cheese - Boursin, Garlic / Herbs
#
#                                            2  \
# CustomerID
# 61288                    Chicken - Soup Base
# 77352                    Oranges - Navel, 72
# 40094                    Pasta - Orecchiette
# 23548                    Flavouring - Orange
# 78981                  Pop Shoppe Cream Soda
# 83106        Soup - Campbells Tomato Ravioli
# 11253                     Tomatoes Tear Drop
# 35107                            Fuji Apples
# 15088                             Watercress
# 26031                    Cheese - Mozzarella
# 86595                     Doilies - 5, Paper
# 46715                                 Garlic
# 91013                   Bread Foccacia Whole
# 69931                         Fond - Neutral
# 19753                     Tomatoes Tear Drop
# 9546           Longos - Grilled Chicken With
# 10224                    Juice - Apple Cider
# 72846       Soup Campbells - Italian Wedding
# 28976                       V8 - Berry Blend
# 3267                    Curry Paste - Madras
# 19260                      Lettuce - Treviso
# 76530                     Beef - Rib Eye Aaa
# 30196                   Ezy Change Mophandle
# 48818        Soup - Campbells Tomato Ravioli
# 15166                           Durian Fruit
# 11443                 Muffin - Zero Transfat
# 79060                   Beans - Kidney White
# 82597                Olive - Spread Tapenade
# 62411          Bread Crumbs - Japanese Style
# 42611                 Cake - Mini Cheesecake
# ...                                      ...
# 95034               Garlic - Primerba, Paste
# 5986                 Wine - Chardonnay South
# 88159                Meldea Green Tea Liquor
# 17458                  Spoon - Soup, Plastic
# 93505                       Chocolate - Dark
# 46826                                 Garlic
# 15371                   Thyme - Lemon, Fresh
# 49981                     Lentils - Red, Dry
# 79353               Tomato - Tricolor Cherry
# 57991                Bandage - Flexible Neon
# 6734                Kellogs Special K Cereal
# 2902         Muffin - Carrot Individual Wrap
# 86136                       Vinegar - Sherry
# 33051                         Fenngreek Seed
# 3253                Cheese - Parmesan Grated
# 33320        Ice - Clear, 300 Lb For Carving
# 62719                       Eggplant - Asian
# 12852                Yogurt - French Vanilla
# 76796               Seedlings - Mix, Organic
# 10114                    Beef - Inside Round
# 25270                 Muffin Batt - Choc Chk
# 17390                              Tia Maria
# 97029                       Chocolate - Dark
# 38154                   Liners - Baking Cups
# 74403          Chips Potato Salt Vinegar 43g
# 49005            Mayonnaise - Individual Pkg
# 41286                        Tea - Earl Grey
# 85878        Muffin - Carrot Individual Wrap
# 68506                     Tea - Decaf Lipton
# 3472                           Pork - Kidney
#
#                                             3  \
# CustomerID
# 61288                 Wine - Chardonnay South
# 77352               Ecolab - Mikroklene 4/4 L
# 40094                         Quiche Assorted
# 23548          Chocolate - Semi Sweet, Calets
# 78981                     Beef - Inside Round
# 83106                      Beef - Rib Eye Aaa
# 11253               Juice - Cranberry, 341 Ml
# 35107                    Dc Hikiage Hira Huba
# 15088                    Curry Paste - Madras
# 26031                 Olive - Spread Tapenade
# 86595                            Broom - Corn
# 46715                       Assorted Desserts
# 91013             Oil - Shortening,liqud, Fry
# 69931                    Pecan Raisin - Tarts
# 19753             Pork - Bacon, Double Smoked
# 9546                         Vaccum Bag 10x13
# 10224         Bread - Italian Roll With Herbs
# 72846                   Rice - Jasmine Sented
# 28976       Beer - Alexander Kieths, Pale Ale
# 3267                 Cheese - Parmesan Grated
# 19260                 Wine - Chardonnay South
# 76530                      Tea - Jasmin Green
# 30196                                  Loquat
# 48818              Wine - Magnotta - Belpaese
# 15166           Gloves - Goldtouch Disposable
# 11443                          Rabbit - Whole
# 79060            Wine - Charddonnay Errazuriz
# 82597              Cookie Chocolate Chip With
# 62411                            Broom - Corn
# 42611            Nantucket - Pomegranate Pear
# ...                                       ...
# 95034            Veal - Brisket, Provimi,bnls
# 5986          Muffin - Carrot Individual Wrap
# 88159                     Veal - Eye Of Round
# 17458              Wine - Gato Negro Cabernet
# 93505                     Tuna - Salad Premix
# 46826                                 Campari
# 15371           Island Oasis - Mango Daiquiri
# 49981                  Longos - Chicken Wings
# 79353                           Hersey Shakes
# 57991                Cheese - Taleggio D.o.p.
# 6734          Muffin - Carrot Individual Wrap
# 2902         Soup Campbells - Italian Wedding
# 86136              Salmon - Atlantic, Skin On
# 33051               Placemat - Scallop, White
# 3253                             Juice - Lime
# 33320               Appetizer - Sausage Rolls
# 62719                          Apricots Fresh
# 12852                Cod - Black Whole Fillet
# 76796              Bacardi Breezer - Tropical
# 10114              Wine - Gato Negro Cabernet
# 25270                    Lamb - Pieces, Diced
# 17390                            Cocoa Butter
# 97029                      Beer - Labatt Blue
# 38154           Ice Cream Bar - Hageen Daz To
# 74403                            Sherry - Dry
# 49005                           Cumin - Whole
# 41286                          Rabbit - Whole
# 85878                             Bread - Rye
# 68506                          Black Currants
# 3472           Pasta - Detalini, White, Fresh
#
#                                            4
# CustomerID
# 61288                              Milk - 1%
# 77352              Shrimp - Baby, Warm Water
# 40094                    Tuna - Salad Premix
# 23548                      Lettuce - Treviso
# 78981                      Sprouts - Alfalfa
# 83106             Wine - Chablis 2003 Champs
# 11253                          Cumin - Whole
# 35107                   Beef - Prime Rib Aaa
# 15088                  Pepper - Black, Whole
# 26031                    Juice - Apple Cider
# 86595                   Sun - Dried Tomatoes
# 46715            Cake - Box Window 10x10x2.5
# 91013                Wine - Redchard Merritt
# 69931                      Tilapia - Fillets
# 19753                       Onions - Vidalia
# 9546                        V8 - Berry Blend
# 10224                Pork - Loin, Center Cut
# 72846                          Lamb - Ground
# 28976                      Pail For Lid 1537
# 3267                                 Mangoes
# 19260                            Beer - Blue
# 76530                         Fenngreek Seed
# 30196                             Watercress
# 48818                 Sobe - Tropical Energy
# 15166                       Salsify, Organic
# 11443             Hot Chocolate - Individual
# 79060       Longos - Grilled Salmon With Bbq
# 82597                     Beef - Rib Eye Aaa
# 62411                 Ocean Spray - Ruby Red
# 42611                   Ezy Change Mophandle
# ...                                      ...
# 95034                   Lettuce - Spring Mix
# 5986                    Coffee - Irish Cream
# 88159                 Nut - Chestnuts, Whole
# 17458                Chinese Foods - Chicken
# 93505                     Cheese - Camembert
# 46826                          Wasabi Powder
# 15371             Potatoes - Idaho 100 Count
# 49981            Cake - Box Window 10x10x2.5
# 79353                     Tea - Jasmin Green
# 57991                    Coffee - Dark Roast
# 6734        Pail With Metal Handle 16l White
# 2902                       Butter - Unsalted
# 86136          Ice Cream Bar - Hageen Daz To
# 33051                            Milk Powder
# 3253                         Quiche Assorted
# 33320                     Bread - Multigrain
# 62719          Wine - Vidal Icewine Magnotta
# 12852                      Lettuce - Treviso
# 76796                               Sardines
# 10114          Wine - Blue Nun Qualitatswein
# 25270                   Lime Cordial - Roses
# 17390                       V8 - Berry Blend
# 97029                               Bay Leaf
# 38154                 Muffin Mix - Blueberry
# 74403                     Pork - Belly Fresh
# 49005                               Sardines
# 41286                  Veal - Inside, Choice
# 85878               Mushrooms - Black, Dried
# 68506                           Cocoa Butter
# 3472                     Raspberries - Fresh
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, cosine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
cuadradobraycurtis = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'braycurtis'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradobraycurtis.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.532520  0.565421  0.550459  0.538136  0.540179
# 200         0.532520  1.000000  0.540323  0.536290  0.514706  0.523438
# 264         0.565421  0.540323  1.000000  0.534783  0.555556  0.529915
# 356         0.550459  0.536290  0.534783  1.000000  0.533058  0.525641
# 412         0.538136  0.514706  0.555556  0.533058  1.000000  0.532787
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.524793  0.527027  0.530702  0.536036  ...  0.501970  0.501583
# 200         0.546875  0.520000  0.540323  0.545455  ...  0.503643  0.502834
# 264         0.532787  0.517241  0.529915  0.525862  ...  0.503380  0.502215
# 356         0.533058  0.545872  0.521186  0.526087  ...  0.502532  0.501899
# 412         0.544000  0.547826  0.528455  0.542373  ...  0.501960  0.503795
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.502423  0.501067  0.502352  0.501227  0.502027  0.501535
# 200         0.504222  0.503541  0.502921  0.502134  0.504913  0.503054
# 264         0.502418  0.502849  0.503529  0.504313  0.503478  0.503073
# 356         0.502724  0.502493  0.502349  0.502457  0.501155  0.503075
# 412         0.502410  0.502837  0.502927  0.503062  0.501727  0.502754
#
# CustomerID     98185     98200
# CustomerID
# 33          0.501517  0.502317
# 200         0.502011  0.502011
# 264         0.503293  0.502313
# 356         0.503040  0.502606
# 412         0.503537  0.504340
#
# [5 rows x 1000 columns]

# %%
Rbraycurtis=dict()
lbraycurtis= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradobraycurtis.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rbraycurtis['CustomerID']= cliente
    Rbraycurtis[0]=top5.ProductName[0]
    Rbraycurtis[1]=top5.ProductName[1]
    Rbraycurtis[2]=top5.ProductName[2]
    Rbraycurtis[3]=top5.ProductName[3]
    Rbraycurtis[4]=top5.ProductName[4]
    lbraycurtis.append(Rbraycurtis.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [1577, 264, 3531, 3909, 756]

# %%
cuadradocanberra = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'canberra'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradocanberra.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.008621  0.010638  0.010101  0.009091  0.009615
# 200         0.008621  1.000000  0.008696  0.008621  0.007519  0.008130
# 264         0.010638  0.008696  1.000000  0.009259  0.009524  0.009009
# 356         0.010101  0.008621  0.009259  1.000000  0.008772  0.008929
# 412         0.009091  0.007519  0.009524  0.008772  1.000000  0.008696
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.008621  0.009434  0.009259  0.009615  ...  0.008233  0.008649
# 200         0.008547  0.008264  0.008696  0.009009  ...  0.007813  0.008045
# 264         0.008696  0.008850  0.009009  0.009009  ...  0.008398  0.008587
# 356         0.008772  0.010000  0.008772  0.009091  ...  0.008244  0.008581
# 412         0.008696  0.009524  0.008547  0.009174  ...  0.007665  0.008541
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.008667  0.009028  0.008519  0.008425  0.008371  0.008502
# 200         0.008202  0.008604  0.007798  0.007784  0.008217  0.007985
# 264         0.008447  0.009226  0.008615  0.009015  0.008541  0.008678
# 356         0.008598  0.009220  0.008376  0.008592  0.008020  0.008754
# 412         0.008040  0.008742  0.008050  0.008249  0.007720  0.008176
#
# CustomerID     98185     98200
# CustomerID
# 33          0.007661  0.008447
# 200         0.007073  0.007549
# 264         0.007937  0.008238
# 356         0.007932  0.008382
# 412         0.007638  0.008344
#
# [5 rows x 1000 columns]

# %%
Rcanberra=dict()
lcanberra= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradocanberra.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rcanberra['CustomerID']= cliente
    Rcanberra[0]=top5.ProductName[0]
    Rcanberra[1]=top5.ProductName[1]
    Rcanberra[2]=top5.ProductName[2]
    Rcanberra[3]=top5.ProductName[3]
    Rcanberra[4]=top5.ProductName[4]
    lcanberra.append(Rcanberra.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [10016, 3909, 14913, 4261, 264]

# %%
cuadradochebyshev = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'chebyshev'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradochebyshev.head(5)
# Out:
# CustomerID  33     200    264    356    412    464    477    639    649    \
# CustomerID
# 33            1.0    0.5    0.5    0.5    0.5    0.5    0.5    0.5    0.5
# 200           0.5    1.0    0.5    0.5    0.5    0.5    0.5    0.5    0.5
# 264           0.5    0.5    1.0    0.5    0.5    0.5    0.5    0.5    0.5
# 356           0.5    0.5    0.5    1.0    0.5    0.5    0.5    0.5    0.5
# 412           0.5    0.5    0.5    0.5    1.0    0.5    0.5    0.5    0.5
#
# CustomerID  669    ...     97697     97753     97769     97793     97900  \
# CustomerID         ...
# 33            0.5  ...  0.038462  0.038462  0.038462  0.038462  0.038462
# 200           0.5  ...  0.038462  0.038462  0.038462  0.038462  0.038462
# 264           0.5  ...  0.038462  0.038462  0.038462  0.038462  0.038462
# 356           0.5  ...  0.038462  0.038462  0.038462  0.038462  0.038462
# 412           0.5  ...  0.038462  0.038462  0.038462  0.038462  0.038462
#
# CustomerID     97928     98069     98159     98185     98200
# CustomerID
# 33          0.038462  0.038462  0.038462  0.038462  0.038462
# 200         0.038462  0.038462  0.038462  0.038462  0.038462
# 264         0.038462  0.038462  0.038462  0.038462  0.038462
# 356         0.038462  0.038462  0.038462  0.038462  0.038462
# 412         0.038462  0.038462  0.038462  0.038462  0.038462
#
# [5 rows x 1000 columns]

# %%
Rchebyshev=dict()
lchebyshev= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradochebyshev.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rchebyshev['CustomerID']= cliente
    Rchebyshev[0]=top5.ProductName[0]
    Rchebyshev[1]=top5.ProductName[1]
    Rchebyshev[2]=top5.ProductName[2]
    Rchebyshev[3]=top5.ProductName[3]
    Rchebyshev[4]=top5.ProductName[4]
    lchebyshev.append(Rchebyshev.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [2187, 2503, 2556, 2566, 2582]

# %%
cuadradocityblock = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'cityblock'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradocityblock.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.008621  0.010638  0.010101  0.009091  0.009615
# 200         0.008621  1.000000  0.008696  0.008621  0.007519  0.008130
# 264         0.010638  0.008696  1.000000  0.009259  0.009524  0.009009
# 356         0.010101  0.008621  0.009259  1.000000  0.008772  0.008929
# 412         0.009091  0.007519  0.009524  0.008772  1.000000  0.008696
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.008621  0.009434  0.009259  0.009615  ...  0.000565  0.000635
# 200         0.008547  0.008264  0.008696  0.009009  ...  0.000564  0.000633
# 264         0.008696  0.008850  0.009009  0.009009  ...  0.000567  0.000635
# 356         0.008772  0.010000  0.008772  0.009091  ...  0.000565  0.000635
# 412         0.008696  0.009524  0.008547  0.009174  ...  0.000562  0.000637
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.000608  0.000712  0.000590  0.000615  0.000581  0.000615
# 200         0.000608  0.000713  0.000587  0.000612  0.000583  0.000614
# 264         0.000607  0.000716  0.000592  0.000621  0.000583  0.000618
# 356         0.000608  0.000715  0.000590  0.000617  0.000578  0.000618
# 412         0.000605  0.000713  0.000589  0.000616  0.000577  0.000615
#
# CustomerID     98185     98200
# CustomerID
# 33          0.000507  0.000582
# 200         0.000505  0.000577
# 264         0.000510  0.000581
# 356         0.000509  0.000582
# 412         0.000509  0.000583
#
# [5 rows x 1000 columns]

# %%
Rcityblock=dict()
lcityblock= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradocityblock.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rcityblock['CustomerID']= cliente
    Rcityblock[0]=top5.ProductName[0]
    Rcityblock[1]=top5.ProductName[1]
    Rcityblock[2]=top5.ProductName[2]
    Rcityblock[3]=top5.ProductName[3]
    Rcityblock[4]=top5.ProductName[4]
    lcityblock.append(Rcityblock.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [3909, 264, 3531, 2503, 3305]

# %%
cuadradocorrelation = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'correlation'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradocorrelation.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.493805  0.529875  0.515035  0.500570  0.504367
# 200         0.493805  1.000000  0.500545  0.496849  0.472695  0.483532
# 264         0.529875  0.500545  1.000000  0.498278  0.517080  0.493067
# 356         0.515035  0.496849  0.498278  1.000000  0.494727  0.489104
# 412         0.500570  0.472695  0.517080  0.494727  1.000000  0.494101
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.487132  0.492406  0.494838  0.500815  ...  0.491005  0.486159
# 200         0.504988  0.481550  0.500545  0.506509  ...  0.508587  0.496849
# 264         0.494101  0.481681  0.493067  0.489652  ...  0.511597  0.493648
# 356         0.494727  0.510742  0.484642  0.490190  ...  0.498600  0.489643
# 412         0.503354  0.510747  0.489748  0.504478  ...  0.485869  0.513118
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.498339  0.480313  0.497157  0.480750  0.492063  0.485173
# 200         0.517060  0.506602  0.497813  0.487096  0.528445  0.499846
# 264         0.496434  0.502956  0.513787  0.526176  0.513045  0.506386
# 356         0.501690  0.498569  0.495876  0.497664  0.478039  0.507100
# 412         0.492877  0.499410  0.500310  0.502343  0.482847  0.497874
#
# CustomerID     98185     98200
# CustomerID
# 33          0.482914  0.496579
# 200         0.483420  0.484852
# 264         0.510648  0.494672
# 356         0.507023  0.499809
# 412         0.510144  0.522382
#
# [5 rows x 1000 columns]

# %%
Rcorrelation=dict()
lcorrelation= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradocorrelation.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rcorrelation['CustomerID']= cliente
    Rcorrelation[0]=top5.ProductName[0]
    Rcorrelation[1]=top5.ProductName[1]
    Rcorrelation[2]=top5.ProductName[2]
    Rcorrelation[3]=top5.ProductName[3]
    Rcorrelation[4]=top5.ProductName[4]
    lcorrelation.append(Rcorrelation.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [10016, 27672, 45786, 38265, 5224]

# %%
cuadradocosine = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'cosine'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradocosine.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.532692  0.565443  0.550466  0.538239  0.540192
# 200         0.532692  1.000000  0.540444  0.536424  0.514712  0.523506
# 264         0.565443  0.540444  1.000000  0.534784  0.555621  0.529915
# 356         0.550466  0.536424  0.534784  1.000000  0.533110  0.525642
# 412         0.538239  0.514712  0.555621  0.533110  1.000000  0.532824
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.524859  0.527028  0.530712  0.536037  ...  0.529019  0.521742
# 200         0.546896  0.520122  0.540444  0.545661  ...  0.550794  0.536424
# 264         0.532824  0.517251  0.529915  0.525866  ...  0.550500  0.530173
# 356         0.533110  0.545887  0.521187  0.526088  ...  0.537266  0.525862
# 412         0.544000  0.547992  0.528487  0.542463  ...  0.526924  0.551365
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.534813  0.513650  0.534245  0.516959  0.529475  0.521380
# 200         0.557488  0.543589  0.539102  0.527408  0.569724  0.540096
# 264         0.533903  0.537132  0.551752  0.563065  0.551325  0.543480
# 356         0.538805  0.532472  0.533641  0.534488  0.516147  0.543866
# 412         0.532274  0.535338  0.540327  0.541355  0.523256  0.536914
#
# CustomerID     98185     98200
# CustomerID
# 33          0.523291  0.533971
# 200         0.528386  0.526533
# 264         0.551922  0.533084
# 356         0.547973  0.537860
# 412         0.553549  0.562502
#
# [5 rows x 1000 columns]

# %%
Rcosine=dict()
lcosine= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradocosine.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rcosine['CustomerID']= cliente
    Rcosine[0]=top5.ProductName[0]
    Rcosine[1]=top5.ProductName[1]
    Rcosine[2]=top5.ProductName[2]
    Rcosine[3]=top5.ProductName[3]
    Rcosine[4]=top5.ProductName[4]
    lcosine.append(Rcosine.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [27672, 10016, 60862, 76532, 85766]

# %%
cuadradomahalanobis = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'mahalanobis'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradomahalanobis.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.223809  0.246158  0.226607  0.235571  0.223056
# 200         0.223809  1.000000  0.216018  0.212059  0.213119  0.217282
# 264         0.246158  0.216018  1.000000  0.222772  0.224746  0.209379
# 356         0.226607  0.212059  0.222772  1.000000  0.216621  0.213005
# 412         0.235571  0.213119  0.224746  0.216621  1.000000  0.219658
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.215632  0.217401  0.224951  0.226557  ...  0.033655  0.033976
# 200         0.219524  0.210211  0.230890  0.219110  ...  0.033765  0.034040
# 264         0.213120  0.204069  0.213768  0.206947  ...  0.033581  0.034065
# 356         0.224125  0.232875  0.211539  0.219396  ...  0.033864  0.034032
# 412         0.213812  0.223039  0.228258  0.231841  ...  0.033687  0.034298
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.034061  0.034247  0.034071  0.034016  0.033896  0.033898
# 200         0.034234  0.034274  0.034158  0.034161  0.034199  0.034008
# 264         0.034012  0.034369  0.034117  0.034139  0.034050  0.033920
# 356         0.034091  0.034409  0.034079  0.033963  0.033805  0.033946
# 412         0.034114  0.034340  0.033844  0.034070  0.033918  0.033823
#
# CustomerID     98185     98200
# CustomerID
# 33          0.033483  0.033942
# 200         0.033545  0.033961
# 264         0.033721  0.033944
# 356         0.033667  0.034077
# 412         0.033682  0.034118
#
# [5 rows x 1000 columns]

# %%
Rmahalanobis=dict()
lmahalanobis= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradomahalanobis.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rmahalanobis['CustomerID']= cliente
    Rmahalanobis[0]=top5.ProductName[0]
    Rmahalanobis[1]=top5.ProductName[1]
    Rmahalanobis[2]=top5.ProductName[2]
    Rmahalanobis[3]=top5.ProductName[3]
    Rmahalanobis[4]=top5.ProductName[4]
    lmahalanobis.append(Rmahalanobis.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [264, 3535, 2187, 3317, 756]

# %%
cuadradominkowski = pd.DataFrame(1/(1 + squareform(pdist(tablita.T, 'minkowski'))), index = tablita.columns, columns = tablita.columns)

# %%
cuadradominkowski.head(5)
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.085297  0.093953  0.091747  0.087410  0.089695
# 200         0.085297  1.000000  0.085638  0.085297  0.080070  0.083020
# 264         0.093953  0.085638  1.000000  0.088152  0.089301  0.087047
# 356         0.091747  0.085297  0.088152  1.000000  0.085983  0.086688
# 412         0.087410  0.080070  0.089301  0.085983  1.000000  0.085638
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.085297  0.088913  0.088152  0.089695  ...  0.004809  0.005108
# 200         0.084959  0.083651  0.085638  0.087047  ...  0.004825  0.005121
# 264         0.085638  0.086333  0.087047  0.087047  ...  0.004822  0.005115
# 356         0.085983  0.091325  0.085983  0.087410  ...  0.004814  0.005111
# 412         0.085638  0.089301  0.084959  0.087779  ...  0.004808  0.005131
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.004996  0.005421  0.004920  0.005023  0.004880  0.005026
# 200         0.005014  0.005448  0.004925  0.005032  0.004909  0.005042
# 264         0.004996  0.005441  0.004932  0.005055  0.004894  0.005042
# 356         0.004999  0.005437  0.004920  0.005036  0.004871  0.005042
# 412         0.004996  0.005441  0.004925  0.005042  0.004876  0.005039
#
# CustomerID     98185     98200
# CustomerID
# 33          0.004549  0.004883
# 200         0.004553  0.004879
# 264         0.004566  0.004883
# 356         0.004563  0.004886
# 412         0.004568  0.004903
#
# [5 rows x 1000 columns]

# %%
Rminkowski=dict()
lminkowski= []
clientes = data.CustomerID.unique()

for cliente in clientes:
    lista = cuadradominkowski.sort_values([cliente], ascending=False).head(6).reset_index()
    iguales = list(lista.CustomerID[1:])
    productos2 = productos.reset_index()
    productos2.set_index(['CustomerID'], inplace = True)
    acotado = productos2.loc[productos2.index.isin(iguales)]
    simi = pd.DataFrame(acotado.groupby(['ProductName'])['Quantity'].sum().sort_values(ascending=False))
    simi.reset_index(inplace=True)
    treintaytres = data[data['CustomerID']==cliente]
    productos33 = pd.DataFrame(treintaytres.groupby('ProductName')['Quantity'].sum())
    productos33.reset_index(inplace = True)
    df_inner = pd.merge(simi, productos33, on='ProductName', how='left')
    nocomprados = df_inner[df_inner.Quantity_y.isna()]
    nocomprados2 = nocomprados.reset_index()
    nocomprados3 = nocomprados2.drop(columns = ['index', 'Quantity_y'])
    top5 = nocomprados3.head(5)
    Rminkowski['CustomerID']= cliente
    Rminkowski[0]=top5.ProductName[0]
    Rminkowski[1]=top5.ProductName[1]
    Rminkowski[2]=top5.ProductName[2]
    Rminkowski[3]=top5.ProductName[3]
    Rminkowski[4]=top5.ProductName[4]
    lminkowski.append(Rminkowski.copy())
    if cliente == 33:
        print(lista.CustomerID[0])
        print(iguales)
# Out:
# 33
# [3909, 3531, 264, 2503, 3305]

# %% [markdown]
# # Recomendaciones por los diferentes métodos

# %%
braycurtis = pd.DataFrame(lbraycurtis)
braycurtis.set_index('CustomerID', inplace = True)
braycurtis.head(5)
# Out:
#                                         0                            1  \
# CustomerID
# 61288         Cheese - Brie, Triple Creme            Snapple Lemon Tea
# 77352                 Garbag Bags - Black       Browning Caramel Glace
# 40094          Wine - Sogrape Mateus Rose    Juice - Cranberry, 341 Ml
# 23548                 Cheese Cloth No 100  Sponge Cake Mix - Chocolate
# 78981       Wine - Blue Nun Qualitatswein                Baking Powder
#
#                                     2                           3  \
# CustomerID
# 61288       Coconut - Shredded, Sweet     Meldea Green Tea Liquor
# 77352        Water - Aquafina Vitamin                   Tia Maria
# 40094        Snapple - Iced Tea Peach              Rosemary - Dry
# 23548        Kellogs Special K Cereal                   Milk - 2%
# 78981         Cheese - Cottage Cheese  Salmon - Atlantic, Skin On
#
#                                    4
# CustomerID
# 61288       Water - Aquafina Vitamin
# 77352            Flavouring - Orange
# 40094                 Spinach - Baby
# 23548           Lamb - Pieces, Diced
# 78981                   Cocoa Butter

# %%
canberra = pd.DataFrame(lcanberra)
canberra.set_index('CustomerID', inplace = True)
canberra.head(5)
# Out:
#                                             0  \
# CustomerID
# 61288       Appetizer - Mini Egg Roll, Shrimp
# 77352                               Grenadine
# 40094                    Cinnamon Buns Sticky
# 23548              Sauce - Gravy, Au Jus, Mix
# 78981                           Duck - Breast
#
#                                            1  \
# CustomerID
# 61288       Wine - White, Schroder And Schyl
# 77352             Wine - Red, Colio Cabernet
# 40094         Wine - Magnotta, Merlot Sr Vqa
# 23548                     Beef - Rib Eye Aaa
# 78981                 Muffin - Zero Transfat
#
#                                            2                     3  \
# CustomerID
# 61288       Pail With Metal Handle 16l White     Assorted Desserts
# 77352               Wine - White Cab Sauv.on  Beef - Prime Rib Aaa
# 40094            Sponge Cake Mix - Chocolate     Pail For Lid 1537
# 23548                Napkin White - Starched  Lamb - Pieces, Diced
# 78981                  Cookie Dough - Double  Lamb - Pieces, Diced
#
#                                          4
# CustomerID
# 61288        Beef - Tenderlion, Center Cut
# 77352                 Garbage Bags - Clear
# 40094                Turkey - Whole, Fresh
# 23548            Beef - Texas Style Burger
# 78981       French Pastry - Mini Chocolate

# %%
chebyshev = pd.DataFrame(lchebyshev)
chebyshev.set_index('CustomerID', inplace = True)
chebyshev.head(5)
# Out:
#                                   0                                  1  \
# CustomerID
# 61288                   Blueberries                Cheese - Mozzarella
# 77352       Bandage - Flexible Neon                            Mangoes
# 40094         Turkey - Whole, Fresh                       Phyllo Dough
# 23548         Kellogs All Bran Bars      Wine - Ej Gallo Sierra Valley
# 78981                       Mangoes  Wine - Vineland Estate Semi - Dry
#
#                                      2                           3  \
# CustomerID
# 61288       Wine - Two Oceans Cabernet  Soup - Campbells, Cream Of
# 77352       Sole - Dover, Whole, Fresh     Chicken - Leg, Boneless
# 40094                 Olives - Stuffed    Kellogs Special K Cereal
# 23548          Meldea Green Tea Liquor             Oil - Safflower
# 78981               Tomatoes Tear Drop              Apricots Fresh
#
#                                    4
# CustomerID
# 61288              Snapple Lemon Tea
# 77352              Wiberg Super Cure
# 40094                 Rosemary - Dry
# 23548       Nut - Pistachio, Shelled
# 78981               Lettuce - Frisee

# %%
cityblock = pd.DataFrame(lcityblock)
cityblock.set_index('CustomerID', inplace = True)
cityblock.head(5)
# Out:
#                                           0                                 1  \
# CustomerID
# 61288                         Pork - Kidney  Cheese - Boursin, Garlic / Herbs
# 77352                     Veal - Sweetbread   Soup - Campbells Tomato Ravioli
# 40094                     Butter - Unsalted                         Tia Maria
# 23548       Soup - Campbells Tomato Ravioli         Beef - Texas Style Burger
# 78981                            Watercress                 Veal - Sweetbread
#
#                                         2                             3  \
# CustomerID
# 61288       Ice Cream Bar - Hageen Daz To                      Bay Leaf
# 77352                           Tia Maria               Sausage - Liver
# 40094                        Sugar - Fine  Soup - Campbells Bean Medley
# 23548           Juice - Cranberry, 341 Ml             Veal - Sweetbread
# 78981               Knife Plastic - White                 Hersey Shakes
#
#                                         4
# CustomerID
# 61288       Wine - Ej Gallo Sierra Valley
# 77352                        Juice - Lime
# 40094            Cod - Black Whole Fillet
# 23548                       Lamb - Ground
# 78981                       Cumin - Whole

# %%
correlation = pd.DataFrame(lcorrelation)
correlation.set_index('CustomerID', inplace = True)
correlation.head(5)
# Out:
#                                          0                            1  \
# CustomerID
# 61288                          Blueberries   Wine - Magnotta - Cab Sauv
# 77352                  Juice - Apple Cider                    Grenadine
# 40094       Bread - Roll, Soft White Round  Mayonnaise - Individual Pkg
# 23548                    Zucchini - Yellow   Wine - Crozes Hermitage E.
# 78981                     Mussels - Frozen                 Onion Powder
#
#                                           2                              3  \
# CustomerID
# 61288       Wine - Red, Harrow Estates, Cab  Chips Potato Salt Vinegar 43g
# 77352                  Garbage Bags - Clear                        Mangoes
# 40094                   Beef - Inside Round           Truffle Cups - Brown
# 23548                Wine - Ruffino Chianti               Olives - Stuffed
# 78981            Bread - Raisin Walnut Oval                     Sauerkraut
#
#                                   4
# CustomerID
# 61288            Lentils - Red, Dry
# 77352       Crab - Imitation Flakes
# 40094             Juice - V8 Splash
# 23548             Crackers Cheez It
# 78981          Garbage Bags - Clear

# %%
cosine = pd.DataFrame(lcosine)
cosine.set_index('CustomerID', inplace = True)
cosine.head(5)
# Out:
#                                   0                               1  \
# CustomerID
# 61288             Foam Dinner Plate     Cheese - Brie, Triple Creme
# 77352                       Mangoes                Lettuce - Frisee
# 40094          Truffle Cups - Brown  Bread - Roll, Soft White Round
# 23548             Crackers Cheez It         Bandage - Flexible Neon
# 78981       Cheese - Cottage Cheese                   Baking Powder
#
#                                     2                         3  \
# CustomerID
# 61288       Ecolab - Mikroklene 4/4 L       Sauce - Hollandaise
# 77352               Zucchini - Yellow            Apricots Fresh
# 40094               Juice - V8 Splash       Beef - Inside Round
# 23548              Cookies Cereal Nut  Beef - Top Sirloin - Aaa
# 78981                Mussels - Frozen              Onion Powder
#
#                                       4
# CustomerID
# 61288        Yogurt - Blueberry, 175 Gr
# 77352               Juice - Apple Cider
# 40094            Pants Custom Dry Clean
# 23548       Mayonnaise - Individual Pkg
# 78981        Bread - Raisin Walnut Oval

# %%
mahalanobis = pd.DataFrame(lmahalanobis)
mahalanobis.set_index('CustomerID', inplace = True)
mahalanobis.head(5)
# Out:
#                                        0                          1  \
# CustomerID
# 61288         Smirnoff Green Apple Twist         Crush - Cream Soda
# 77352         Smirnoff Green Apple Twist  Appetizer - Sausage Rolls
# 40094              Pop Shoppe Cream Soda        Sausage - Breakfast
# 23548       Soup - Campbells Bean Medley              Sage - Ground
# 78981              Veal - Inside, Choice     Ocean Spray - Ruby Red
#
#                                2                          3  \
# CustomerID
# 61288       Salmon - Sockeye Raw              Cumin - Whole
# 77352                 Watercress  Macaroons - Two Bite Choc
# 40094           Ketchup - Tomato          Lettuce - Treviso
# 23548                  Milk - 2%                Blueberries
# 78981                Blueberries              Veal - Inside
#
#                                    4
# CustomerID
# 61288       Cod - Black Whole Fillet
# 77352                 Spinach - Baby
# 40094               Sea Bass - Whole
# 23548                       Sardines
# 78981           Curry Paste - Madras

# %%
minkowski = pd.DataFrame(lminkowski)
minkowski.set_index('CustomerID', inplace = True)
minkowski.head(5)
# Out:
#                                    0                               1  \
# CustomerID
# 61288       Mushrooms - Black, Dried  Wine - Magnotta, Merlot Sr Vqa
# 77352                    Guinea Fowl                       Grenadine
# 40094       Water - Mineral, Natural           Oregano - Dry, Rubbed
# 23548                    Wanton Wrap                  Banana Turning
# 78981               Lettuce - Frisee          Longos - Chicken Wings
#
#                                 2                               3  \
# CustomerID
# 61288         Chicken - Soup Base         Wine - Chardonnay South
# 77352         Oranges - Navel, 72       Ecolab - Mikroklene 4/4 L
# 40094         Pasta - Orecchiette                 Quiche Assorted
# 23548         Flavouring - Orange  Chocolate - Semi Sweet, Calets
# 78981       Pop Shoppe Cream Soda             Beef - Inside Round
#
#                                     4
# CustomerID
# 61288                       Milk - 1%
# 77352       Shrimp - Baby, Warm Water
# 40094             Tuna - Salad Premix
# 23548               Lettuce - Treviso
# 78981               Sprouts - Alfalfa
